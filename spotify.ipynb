# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sn

# %%
data=pd.read_csv('SpotifyFeatures.csv')

# %%
print(data.head())
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
print(data.describe())
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# ...

# %%
print(data.columns)
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
data.drop_duplicates(subset=['track_name'],inplace=True)

# %%
data[data['artist_name']=="Nirvana"]
# Out:
#                    genre artist_name  \
# 680          Alternative     Nirvana
# 1112         Alternative     Nirvana
# 1190         Alternative     Nirvana
# 1228         Alternative     Nirvana
# 1378         Alternative     Nirvana
# 1406         Alternative     Nirvana
# 1608         Alternative     Nirvana
# 1609         Alternative     Nirvana
# 1785         Alternative     Nirvana
# 1863         Alternative     Nirvana
# 2649         Alternative     Nirvana
# 2887         Alternative     Nirvana
# 2984         Alternative     Nirvana
# 3050         Alternative     Nirvana
# 3125         Alternative     Nirvana
# 3294         Alternative     Nirvana
# 4758         Alternative     Nirvana
# 4862         Alternative     Nirvana
# 4892         Alternative     Nirvana
# 4919         Alternative     Nirvana
# 4947         Alternative     Nirvana
# 5213         Alternative     Nirvana
# 5397         Alternative     Nirvana
# 5563         Alternative     Nirvana
# ...

# %%
data[data['artist_name']=='Metallica']
# Out:
#        genre artist_name                                 track_name  \
# 153065  Rock   Metallica                            Moth Into Flame
# 153069  Rock   Metallica                           Holier Than Thou
# 153210  Rock   Metallica             The Four Horsemen (Remastered)
# 153245  Rock   Metallica  The Thing That Should Not Be (Remastered)
# 153696  Rock   Metallica          Fight Fire With Fire (Remastered)
# 153797  Rock   Metallica                            Until It Sleeps
# 153836  Rock   Metallica                               Atlas, Rise!
# 153842  Rock   Metallica                            Of Wolf And Man
# 153862  Rock   Metallica                         Orion (Remastered)
# 153963  Rock   Metallica                         The Memory Remains
# 154191  Rock   Metallica                          Through The Never
# 154317  Rock   Metallica                        Now That We're Dead
# 154432  Rock   Metallica                          Spit Out the Bone
# ...

# %%
data.groupby('genre')['artist_name'].value_counts()
# Out:
# genre      artist_name
# A Capella  The Singers Unlimited    36
#            Glad                     21
#            Hyannis Sound            18
#            The King's Singers       18
#            MC6 A Cappella           15
#                                     ..
# World      Wasis Diop                1
#            Windy & Carl              1
#            Zoufris Maracas           1
#            alva noto                 1
#            fhop music                1
# Name: count, Length: 15999, dtype: int64

# %%
data.groupby('genre')['popularity'].mean().sort_values(ascending=False)
# Out:
# genre
# Pop                 66.846063
# Rap                 59.421875
# Hip-Hop             58.713861
# Rock                58.494294
# Dance               57.466487
# Indie               53.375989
# Children’s Music    52.214139
# Alternative         50.491752
# Folk                49.537400
# R&B                 48.875162
# Country             43.625254
# Soul                43.174515
# Jazz                39.703858
# Electronic          37.600758
# Reggaeton           36.673184
# Reggae              35.579033
# World               34.492442
# Soundtrack          33.721638
# Blues               33.635532
# Classical           29.092674
# Ska                 27.781250
# Anime               24.271494
# Comedy              21.353356
# Opera               13.260005
# Movie               11.744638
# A Capella            9.302521
# Children's Music     4.558697
# Name: popularity, dtype: float64

# %%
print(data.groupby('genre')['acousticness'].mean().sort_values(ascending=False))
# Out:
# genre
# Opera               0.945319
# Classical           0.879779
# A Capella           0.829941
# Comedy              0.793344
# Soundtrack          0.707527
# Movie               0.693020
# Children's Music    0.600208
# Jazz                0.503838
# Folk                0.484136
# World               0.389579
# Soul                0.350160
# Blues               0.334030
# R&B                 0.306480
# Indie               0.305768
# Anime               0.291601
# Country             0.272046
# Pop                 0.253851
# Rap                 0.227338
# Reggaeton           0.220737
# Rock                0.210406
# Reggae              0.188284
# Hip-Hop             0.169987
# Alternative         0.160914
# Dance               0.153090
# Children’s Music    0.148563
# Electronic          0.120731
# Ska                 0.088182
# Name: acousticness, dtype: float64

# %%
data.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
data.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
harry=data.groupby('genre')['popularity'].mean().sort_values(ascending=False)

print(harry)
plt.figure(figsize=(12,6))
harry.plot(kind='bar',color='skyblue',edgecolor='black')
plt.title('genre of music with populariy',fontsize=16)
plt.xlabel('genre of music',fontsize=12)
plt.ylabel('popularity',fontsize=12)
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.show()
# Out:
# genre
# Pop                 66.846063
# Rap                 59.421875
# Hip-Hop             58.713861
# Rock                58.494294
# Dance               57.466487
# Indie               53.375989
# Children’s Music    52.214139
# Alternative         50.491752
# Folk                49.537400
# R&B                 48.875162
# Country             43.625254
# Soul                43.174515
# Jazz                39.703858
# Electronic          37.600758
# Reggaeton           36.673184
# Reggae              35.579033
# World               34.492442
# Soundtrack          33.721638
# Blues               33.635532
# Classical           29.092674
# Ska                 27.781250
# Anime               24.271494
# Comedy              21.353356
# Opera               13.260005
# Movie               11.744638
# A Capella            9.302521
# Children's Music     4.558697
# Name: popularity, dtype: float64

# %%
data.groupby('genre').agg({'popularity':['mean','sum','max'],
                                 "energy":['mean','max','sum']}).sort_values(('energy','mean'),ascending=False)
# Out:
#                  popularity                 energy
#                        mean     sum  max      mean    max          sum
# genre
# Ska               27.781250  177800   66  0.839372  0.999  5371.983892
# Reggaeton         36.673184  270098   95  0.750166  0.994  5524.970000
# Electronic        37.600758  297610   84  0.738444  0.999  5844.787000
# Children’s Music  52.214139   50961   86  0.717290  0.994   700.075200
# Alternative       50.491752  419334   83  0.713847  0.998  5928.495700
# Dance             57.466487  383244  100  0.698663  0.999  4659.382900
# Rock              58.494294   97393   84  0.680849  0.997  1133.613000
# Comedy            21.353356  184493   56  0.674413  0.998  5826.928230
# Pop               66.846063  113772   97  0.664505  0.993  1130.988230
# Anime             24.271494  200434   65  0.661232  0.999  5460.457110
# Hip-Hop           58.713861  355806   98  0.647739  0.995  3925.297243
# ...

# %%
harry2=data.groupby('genre')['energy'].mean().sort_values(ascending=False).head(10)
print(harry2)
plt.figure(figsize=(12,6))
harry2.plot(kind='bar',color='red',edgecolor='black')
plt.title('Energy claassifcation with genre',fontsize=18)
plt.xticks(rotation=45,ha='right')
plt.xlabel('genre of music',fontsize=12)
plt.ylabel('energy',fontsize=12)
plt.tight_layout()
plt.grid(axis='y',linestyle='--',alpha=0.5)
plt.show()
# Out:
# genre
# Ska                 0.839372
# Reggaeton           0.750166
# Electronic          0.738444
# Children’s Music    0.717290
# Alternative         0.713847
# Dance               0.698663
# Rock                0.680849
# Comedy              0.674413
# Pop                 0.664505
# Anime               0.661232
# Name: energy, dtype: float64

# %%
correl=data.corr(numeric_only=True)
print(correl)
plt.figure(figsize=(14,8))
sn.heatmap(correl,annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Heat correlation graph")
plt.tight_layout()
plt.show()
# Out:
#                   popularity  acousticness  danceability  duration_ms  \
# popularity          1.000000     -0.380385      0.239787     0.012445
# acousticness       -0.380385      1.000000     -0.395973     0.015643
# danceability        0.239787     -0.395973      1.000000    -0.125266
# duration_ms         0.012445      0.015643     -0.125266     1.000000
# energy              0.253819     -0.735742      0.389246    -0.034028
# instrumentalness   -0.148562      0.311673     -0.382375     0.070520
# liveness           -0.159592      0.077576     -0.016990     0.023645
# loudness            0.333183     -0.699952      0.478192    -0.045139
# speechiness        -0.160027      0.170984      0.141612    -0.009559
# tempo               0.092062     -0.269531      0.059892    -0.032974
# valence             0.071681     -0.361733      0.598338    -0.146343
#
#                     energy  instrumentalness  liveness  loudness  speechiness  \
# ...

# %%
data2=data.groupby("artist_name").size().sort_values(ascending=False).head(20)

# %%
data2
# Out:
# artist_name
# Giuseppe Verdi             1302
# Giacomo Puccini            1087
# Kimbo Children's Music      897
# Wolfgang Amadeus Mozart     799
# Richard Wagner              776
# Nobuo Uematsu               736
# Georges Bizet               673
# Johann Sebastian Bach       629
# Randy Newman                598
# Ludwig van Beethoven        594
# Juice Music                 519
# Hans Zimmer                 477
# Chorus                      475
# Henri Salvador              465
# Gioachino Rossini           455
# Frédéric Chopin             434
# John Williams               429
# Gaetano Donizetti           373
# Dorothée                    372
# Max Richter                 349
# dtype: int64

# %%
plt.figure(figsize=(14,8))
data2.plot(kind='bar',color='blue',edgecolor='black')
plt.title("Top artist_name according to their track count",fontsize=16)
plt.xlabel("artist name")
plt.ylabel("total count")
plt.tight_layout()
plt.show()

# %%
rock_data=data[data['genre'].str.contains('Alternative',case=False,na=False)]

# %%
databy=rock_data.groupby("artist_name")['popularity'].mean().sort_values(ascending=False).reset_index().head(100)

# %%
databy
# Out:
#      artist_name  popularity
# 0     Supergrass        69.0
# 1    Bag Raiders        69.0
# 2   ChocQuibTown        68.0
# 3     Crazy Town        67.0
# 4       La Unión        67.0
# ..           ...         ...
# 95    Spiderbait        58.0
# 96       Mos Def        58.0
# 97   Billy Bragg        58.0
# 98       Ben Lee        58.0
# 99     Amy Grant        58.0
#
# [100 rows x 2 columns]

# %%
print(data.head())
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
data1=data[data['artist_name']=='Nirvana']

# %%
data1.sort_values(by='popularity',ascending=False).head(10)
# Out:
#             genre artist_name                      track_name  \
# 680   Alternative     Nirvana         Smells Like Teen Spirit
# 1190  Alternative     Nirvana                Heart-Shaped Box
# 1112  Alternative     Nirvana                 Come As You Are
# 1378  Alternative     Nirvana      The Man Who Sold The World
# 1609  Alternative     Nirvana  Where Did You Sleep Last Night
# 1228  Alternative     Nirvana                         Lithium
# 1785  Alternative     Nirvana                    About A Girl
# 1608  Alternative     Nirvana                   All Apologies
# 1863  Alternative     Nirvana                    Lake Of Fire
# 1406  Alternative     Nirvana    In Bloom - Nevermind Version
#
#                     track_id  popularity  acousticness  danceability  \
# 680   5ghIJDpPoe3CfHMGu71E6T          72      0.000029         0.516
# 1190  11LmqTE2naFULdEP94AUBa          71      0.184000         0.494
# 1112  4P5KoWXOxwuobLmHXLMobV          70      0.000182         0.505
# ...

# %%
data2=data1.sort_values(by='popularity',ascending=False).head(10)

# %%
plt.figure(figsize=(7,7))
plt.pie(data2['popularity'],labels=data2['track_name'],shadow=True,autopct='%1.1f%%')
plt.title("top nirvana songs according to popularity",fontsize=16,color='darkgreen')
plt.axis('equal')
plt.show()

# %%
data3=data1.sort_values(by='loudness',ascending=False).head(20)
data3['new_sound']=data3['loudness'].apply(lambda x: -x)
data3
# Out:
#                    genre artist_name                     track_name  \
# 4919         Alternative     Nirvana           Territorial Pissings
# 680          Alternative     Nirvana        Smells Like Teen Spirit
# 1785         Alternative     Nirvana                   About A Girl
# 3050         Alternative     Nirvana                          Breed
# 5397         Alternative     Nirvana                     On A Plain
# 11182        Alternative     Nirvana            Downer - Remastered
# 1406         Alternative     Nirvana   In Bloom - Nevermind Version
# 11160        Alternative     Nirvana     Mr. Moustache - Remastered
# 4862         Alternative     Nirvana                      Stay Away
# 5998         Alternative     Nirvana              Blew - Remastered
# 4758         Alternative     Nirvana                     Lounge Act
# 12890        Alternative     Nirvana  Floyd The Barber - Remastered
# 2649         Alternative     Nirvana                      Drain You
# ...

# %%
plt.figure(figsize=(7,7))
plt.pie(data3['popularity'],labels=data3['track_name'],shadow=True,autopct='%1.1f%%')
plt.title("top nirvana songs according to loudness",fontsize=16,color='darkgreen')
plt.axis('equal')
plt.show()

# %%
data1.groupby('mode')['popularity'].mean()
# Out:
# mode
# Major    54.107143
# Minor    55.000000
# Name: popularity, dtype: float64

# %%
data.groupby('key')['danceability'].mean().sort_values(ascending=False)
# Out:
# key
# C#    0.570650
# B     0.565579
# F#    0.559656
# G#    0.550999
# A#    0.546473
# G     0.532141
# A     0.530593
# C     0.524806
# F     0.524119
# E     0.519693
# D     0.511661
# D#    0.482198
# Name: danceability, dtype: float64

# %%
data34=data[data['artist_name']=='Radiohead']

# %%
data34.sort_values(by='popularity',ascending=False).head(20)
# Out:
#              genre artist_name                     track_name  \
# 1481   Alternative   Radiohead                   Karma Police
# 1523   Alternative   Radiohead                   High And Dry
# 2534   Alternative   Radiohead             Fake Plastic Trees
# 2738   Alternative   Radiohead                   No Surprises
# 2869   Alternative   Radiohead               Paranoid Android
# 2875   Alternative   Radiohead          Weird Fishes/ Arpeggi
# 3482   Alternative   Radiohead        Exit Music (For a Film)
# 3411   Alternative   Radiohead  Everything In Its Right Place
# 95642        Indie   Radiohead                    Daydreaming
# 5073   Alternative   Radiohead      Jigsaw Falling Into Place
# 4950   Alternative   Radiohead                       Reckoner
# 5228   Alternative   Radiohead                           Nude
# 4881   Alternative   Radiohead                        15 Step
# 5381   Alternative   Radiohead                   Pyramid Song
# ...

# %%
data[data['artist_name']=="Nirvana"]
# Out:
#                    genre artist_name  \
# 680          Alternative     Nirvana
# 1112         Alternative     Nirvana
# 1190         Alternative     Nirvana
# 1228         Alternative     Nirvana
# 1378         Alternative     Nirvana
# 1406         Alternative     Nirvana
# 1608         Alternative     Nirvana
# 1609         Alternative     Nirvana
# 1785         Alternative     Nirvana
# 1863         Alternative     Nirvana
# 2649         Alternative     Nirvana
# 2887         Alternative     Nirvana
# 2984         Alternative     Nirvana
# 3050         Alternative     Nirvana
# 3125         Alternative     Nirvana
# 3294         Alternative     Nirvana
# 4758         Alternative     Nirvana
# 4862         Alternative     Nirvana
# 4892         Alternative     Nirvana
# 4919         Alternative     Nirvana
# 4947         Alternative     Nirvana
# 5213         Alternative     Nirvana
# 5397         Alternative     Nirvana
# 5563         Alternative     Nirvana
# ...

# %%
data36=data[data['artist_name']=="Metallica"]

# %%
data69=data36.sort_values(by='popularity',ascending=False).head(20)
data69
# Out:
#        genre artist_name                              track_name  \
# 166195  Rock   Metallica                           Enter Sandman
# 166604  Rock   Metallica                        One (Remastered)
# 166689  Rock   Metallica          Master of Puppets (Remastered)
# 167082  Rock   Metallica    For Whom The Bell Tolls (Remastered)
# 222521  Rock   Metallica              Fade To Black (Remastered)
# 222933  Rock   Metallica                     Wherever I May Roam
# 223612  Rock   Metallica                               Hardwired
# 223696  Rock   Metallica                           Turn The Page
# 223797  Rock   Metallica             Seek & Destroy (Remastered)
# 223716  Rock   Metallica                    Battery (Remastered)
# 224783  Rock   Metallica  Welcome Home (Sanitarium) (Remastered)
# 224975  Rock   Metallica                  Blackened (Remastered)
# 225395  Rock   Metallica                       The Unforgiven II
# ...

# %%
plt.figure(figsize=(8,8))
plt.pie(data69['popularity'],labels=data69['track_name'],shadow=True,autopct="%1.1f%%")
plt.title("Top 10 most popular song of Metallica", fontsize=14,color='blue')
plt.axis('equal')
plt.show()

# %%
data['duration_minute']=data['duration_ms'].apply(lambda x: round((x/1000)/60,2))

# %%
data
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232714   Soul                    H-Town                 They Like It Slow
# 232716   Soul               John Legend            Quickly (feat. Brandy)
# 232717   Soul                     Belly                            P.O.P.
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
hacker=data[data['artist_name']=="Nirvana"]

# %%
hacker
# Out:
#                    genre artist_name  \
# 680          Alternative     Nirvana
# 1112         Alternative     Nirvana
# 1190         Alternative     Nirvana
# 1228         Alternative     Nirvana
# 1378         Alternative     Nirvana
# 1406         Alternative     Nirvana
# 1608         Alternative     Nirvana
# 1609         Alternative     Nirvana
# 1785         Alternative     Nirvana
# 1863         Alternative     Nirvana
# 2649         Alternative     Nirvana
# 2887         Alternative     Nirvana
# 2984         Alternative     Nirvana
# 3050         Alternative     Nirvana
# 3125         Alternative     Nirvana
# 3294         Alternative     Nirvana
# 4758         Alternative     Nirvana
# 4862         Alternative     Nirvana
# 4892         Alternative     Nirvana
# 4919         Alternative     Nirvana
# 4947         Alternative     Nirvana
# 5213         Alternative     Nirvana
# 5397         Alternative     Nirvana
# 5563         Alternative     Nirvana
# ...

# %%
hackerrank=data[data['artist_name']=="Metallica"]

# %%
hackerrank.sort_values(by='loudness',ascending=False).head(10)
# Out:
#        genre artist_name                track_name                track_id  \
# 154659  Rock   Metallica        All Nightmare Long  5w3TTTAo6DIEjQYO3vKZq0
# 225925  Rock   Metallica  The Day That Never Comes  2gqzkEF88vMclfRZEIOnQO
# 154977  Rock   Metallica                 St. Anger  3fOc9x06lKJBhz435mInlH
# 223612  Rock   Metallica                 Hardwired  7myke8Id4WyKFlWcRBJdIF
# 153836  Rock   Metallica              Atlas, Rise!  7uSx9pDbxfFsXPyZ4pOm7H
# 153065  Rock   Metallica           Moth Into Flame  5sEcwMeC3QDnSOWlyQyQ3E
# 154492  Rock   Metallica        The Unforgiven III  6guXhXMAHU4QYaEsobnS6v
# 154317  Rock   Metallica       Now That We're Dead  01LODLnhlfNphZ366BqKc0
# 156467  Rock   Metallica               I Disappear  51Vic2Yi71YKNtLbyJKgQt
# 153963  Rock   Metallica        The Memory Remains  0vhOJ8a3M2LWnBNrDXJKDl
#
#         popularity  acousticness  danceability  duration_ms  energy  \
# 154659          52      0.000568         0.271       477013   0.985
# ...

# %%
harryp=data.groupby('genre')['danceability'].mean().sort_values(ascending=False).head(10)

# %%
harryp
plt.figure(figsize=(8,8))
plt.title("Danceabilty according to genre",fontsize=16,color='red')
harryp.plot(kind='barh',edgecolor='black',color='pink')
plt.xlabel('danceability')
plt.ylabel("genre of music")
plt.grid(axis='y',linestyle='--',alpha=0.5)
plt.tight_layout()
plt.show()

# %%
def get_status(score):
    if (score>=80):
       return "HIGH"
    elif(score>=50 and score<=79):
       return "MEDIUM"
    else:
       return "LOW"

data['popularity_status']=data['popularity'].apply(get_status)
data
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232714   Soul                    H-Town                 They Like It Slow
# 232716   Soul               John Legend            Quickly (feat. Brandy)
# 232717   Soul                     Belly                            P.O.P.
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
data[data['artist_name']=="AC/DC"]
# Out:
#        genre artist_name                                         track_name  \
# 153373  Rock       AC/DC                                            Big Gun
# 153554  Rock       AC/DC                                        War Machine
# 153951  Rock       AC/DC                                     Fire Your Guns
# 154634  Rock       AC/DC                                       Rock or Bust
# 154734  Rock       AC/DC                     What Do You Do for Money Honey
# 155737  Rock       AC/DC                                Shot Down in Flames
# 156242  Rock       AC/DC                                         Heatseeker
# 156280  Rock       AC/DC                                             Rocker
# 156340  Rock       AC/DC                               Givin the Dog a Bone
# 166082  Rock       AC/DC                                    Highway to Hell
# 166087  Rock       AC/DC                                      Back In Black
# ...

# %%
data[data['popularity_status']=='HIGH'].head(50)
# Out:
#             genre          artist_name  \
# 671   Alternative                 Joji
# 672   Alternative                 Joji
# 1104  Alternative          Linkin Park
# 9026        Dance        Ariana Grande
# 9027        Dance        Ariana Grande
# 9028        Dance               Halsey
# 9029        Dance        Ariana Grande
# 9030        Dance        Ariana Grande
# 9031        Dance        Ariana Grande
# 9032        Dance        Ariana Grande
# 9033        Dance        Ariana Grande
# 9034        Dance         benny blanco
# 9035        Dance        Ariana Grande
# 9036        Dance                 Lauv
# 9037        Dance              Ava Max
# 9038        Dance        Ariana Grande
# 9039        Dance        Alec Benjamin
# 9040        Dance            Lady Gaga
# 9041        Dance        Ariana Grande
# 9042        Dance       Jonas Brothers
# 9043        Dance            Lady Gaga
# 9044        Dance        Ariana Grande
# 9045        Dance     The Chainsmokers
# ...

# %%
data.groupby('popularity_status')['artist_name'].size()
# Out:
# popularity_status
# HIGH         484
# LOW       115793
# MEDIUM     32331
# Name: artist_name, dtype: int64

# %%
data36=data[data['artist_name']=='Radiohead']
print(data36['popularity_status'].value_counts())
# Out:
# popularity_status
# MEDIUM    49
# LOW       14
# Name: count, dtype: int64

# %%
data.groupby('genre').size().reset_index(name='counts')
# Out:
#                genre  counts
# 0          A Capella     119
# 1        Alternative    8305
# 2              Anime    8258
# 3              Blues    7216
# 4   Children's Music    4174
# 5   Children’s Music     976
# 6          Classical    8395
# 7             Comedy    8640
# 8            Country    6391
# 9              Dance    6669
# 10        Electronic    7915
# 11              Folk    6524
# 12           Hip-Hop    6060
# 13             Indie    2274
# 14              Jazz    5987
# 15             Movie    6947
# 16             Opera    8096
# 17               Pop    1702
# 18               R&B    3869
# 19               Rap    1152
# 20            Reggae    6782
# 21         Reggaeton    7365
# 22              Rock    1665
# 23               Ska    6400
# 24              Soul    2888
# 25        Soundtrack    7422
# 26             World    6417

# %%
data[data['popularity_status']=="MEDIUM"]
# Out:
#        genre       artist_name                                  track_name  \
# 135      R&B     Mary J. Blige                  Be Without You - Kendu Mix
# 136      R&B           Rihanna                                   Desperado
# 137      R&B         Yung Bleu  Ice On My Baby (feat. Kevin Gates) - Remix
# 138      R&B          Surfaces                   Heaven Falls / Fall on Me
# 139      R&B    Olivia O'Brien                                 Love Myself
# ...      ...               ...                                         ...
# 232358  Soul   Detroit Swindle              Yes, No, Maybe feat. Tom Misch
# 232407  Soul       Seinabo Sey                           Never Get Used To
# 232446  Soul     Maribou State                                   The Clown
# 232480  Soul   Lisa Stansfield                   So Be It - Soultalk Remix
# 232502  Soul  Fat Larry's Band                           Act Like You Know
#
# ...

# %%
data69=data[data['artist_name']=="Metallica"]
data69
# Out:
#        genre artist_name                                 track_name  \
# 153065  Rock   Metallica                            Moth Into Flame
# 153069  Rock   Metallica                           Holier Than Thou
# 153210  Rock   Metallica             The Four Horsemen (Remastered)
# 153245  Rock   Metallica  The Thing That Should Not Be (Remastered)
# 153696  Rock   Metallica          Fight Fire With Fire (Remastered)
# 153797  Rock   Metallica                            Until It Sleeps
# 153836  Rock   Metallica                               Atlas, Rise!
# 153842  Rock   Metallica                            Of Wolf And Man
# 153862  Rock   Metallica                         Orion (Remastered)
# 153963  Rock   Metallica                         The Memory Remains
# 154191  Rock   Metallica                          Through The Never
# 154317  Rock   Metallica                        Now That We're Dead
# 154432  Rock   Metallica                          Spit Out the Bone
# ...

# %%
data69.groupby('popularity_status').size()
# Out:
# popularity_status
# MEDIUM    40
# dtype: int64

# %%
data.head(10)
# Out:
#    genre          artist_name  \
# 0  Movie       Henri Salvador
# 1  Movie    Martin & les fées
# 2  Movie      Joseph Williams
# 3  Movie       Henri Salvador
# 4  Movie         Fabien Nataf
# 5  Movie       Henri Salvador
# 6  Movie    Martin & les fées
# 7  Movie          Laura Mayne
# 8  Movie               Chorus
# 9  Movie  Le Club des Juniors
#
#                                           track_name                track_id  \
# 0                        C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1                   Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2                     Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3                     Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                          Ouverture  0IuslXpMROHdEPvSl1fTQK
# 5                     Le petit souper aux chandelles  0Mf1jKa8eNAf1a4PwTbizj
# 6  Premières recherches (par Paul Ventimila, Lori...  0NUiKYRd6jt1LKMYGkUdnZ
# ...

# %%
data54=data[data['genre']=="Rock"]
data54=data54[data54['popularity_status']=="HIGH"].head(10)
data54
# Out:
#        genre  artist_name                                         track_name  \
# 166058  Rock        Queen                Bohemian Rhapsody - Remastered 2011
# 166059  Rock        Queen                     Don't Stop Me Now - Remastered
# 166082  Rock        AC/DC                                    Highway to Hell
# 166087  Rock        AC/DC                                      Back In Black
# 166090  Rock   Elton John  Rocket Man (I Think It's Going To Be A Long, L...
# 166093  Rock        AC/DC                                      Thunderstruck
# 166096  Rock  The Beatles               Here Comes The Sun - Remastered 2009
# 166118  Rock  Tame Impala                         The Less I Know The Better
#
#                       track_id  popularity  acousticness  danceability  \
# 166058  7tFiyTwD0nx5a1eklYtX2J          82      0.254000         0.397
# 166059  7hQJA50XrCWABAu5v6QZ4i          81      0.048800         0.559
# ...

# %%
plt.figure(figsize=(8,8))
plt.pie(data54['popularity'],labels=data54['track_name'],shadow=True, autopct="%1.1f%%")
plt.title("Top 10 most popular rock song of all time",fontsize=14,color="Red")
plt.axis('equal')
plt.show()

# %%
data[data['artist_name']=="Led zeppeline"]
# Out:
# Empty DataFrame
# Columns: [genre, artist_name, track_name, track_id, popularity, acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, time_signature, valence, duration_minute, popularity_status]
# Index: []
